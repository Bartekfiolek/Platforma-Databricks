# %%
print('Hello World')

# %% [markdown]
# Co w większości wpłynie na czas wykonania tak prostego polecenia?

# %%
def kwadrat(x):
    return x*x

# %%
liczba = kwadrat(3)
print(kwadrat(3))

# %% [markdown]
# Jak długo będzie można odwołać się do funkcji kwadrat?

# %% [markdown]
# Notebook ma ustawiony domyślny język python dlatego nie potrzeba podawać magicznej komendy %python. Jeśli w tym samym notebooku chcemy użyć innego języka np. SQL, wtedy wygląda to tak:

# %%
# %sql
SELECT
  first_name,
  last_name,
  product,
  quantity
FROM
  samples.bakehouse.sales_customers as sc
    JOIN samples.bakehouse.sales_transactions as st
      ON sc.customerID = st.customerID;

# %% [markdown]
# Zapoznaj się z danymi w schemacie samples.bakehouse.

# %% [markdown]
# Poproś Genie o wygenerowanie kodu SQL, który wybierze klienta, który kupuje największą liczbę produktów w  piekarni.​
