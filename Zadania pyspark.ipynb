# %% [markdown]
# Używamy pysparka i pracujemy na samples.bakehouse

# %% [markdown]
# Wybierz klientów, których nazwisko zaczyna się na "S". Posortuj ich według nazwiska i imienia.

# %% [markdown]
# Znajdź 3 najczęściej sprzedające się produkty.

# %% [markdown]
# Znajdź całkowity przychód wygenerowany przez każdego klienta.

# %% [markdown]
# Wyznacz wolumen sprzedaży dla każdego produktu i wskaż jaki stanowi procent całkowitego wolumenu sprzedaży.
